# %% [markdown]
# ## Introduction to Probability and Statistics
# ## Assignment
#
# In this assignment, we will use the dataset of diabetes patients taken [from here](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../../data/diabetes.tsv",sep='\t')
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %% [markdown]
# In this dataset, columns as the following:
# * Age and sex are self-explanatory
# * BMI is body mass index
# * BP is average blood pressure
# * S1 through S6 are different blood measurements
# * Y is the qualitative measure of disease progression over one year
#
# Let's study this dataset using methods of probability and statistics.
#
# ### Task 1: Compute mean values and variance for all values

# %%
means = df.mean()
variances = df.var()

print("Means:")
print(means)
print("\nVariances:")
print(variances)
# Out:
# Means:
# AGE     48.518100
# SEX      1.468326
# BMI     26.375792
# BP      94.647014
# S1     189.140271
# S2     115.439140
# S3      49.788462
# S4       4.070249
# S5       4.641411
# S6      91.260181
# Y      152.133484
# dtype: float64
#
# Variances:
# AGE     171.846610
# SEX       0.249561
# BMI      19.519798
# BP      191.304401
# S1     1197.717241
# S2      924.955494
# S3      167.293585
# S4        1.665261
# S5        0.272892
# S6      132.165712
# Y      5943.331348
# dtype: float64

# %% [markdown]
# ### Task 2: Plot boxplots for BMI, BP and Y depending on gender

# %%
for col in ['BMI','BP','Y']:
    df.boxplot(column=col, by='SEX', figsize=(10,8))
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# ### Task 3: What is the the distribution of Age, Sex, BMI and Y variables?

# %%
for col in ['AGE','SEX','BMI','Y']:
    df[col].hist()
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# ### Task 4: Test the correlation between different variables and disease progression (Y)
#
# > **Hint** Correlation matrix would give you the most useful information on which values are dependent.

# %%
df.corr()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# AGE  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# SEX  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# BMI  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# BP   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# S1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# S2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# S3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# S4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# S5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# S6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            S4        S5        S6         Y
# ...

# %%
corr_y = df.corr(numeric_only=True)[['Y']]

plt.figure(figsize=(4, 6))
sns.heatmap(corr_y, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Correlation with Y')
plt.show()

# %% [markdown]
# ### Task 5: Test the hypothesis that the degree of diabetes progression is different between men and women

# %%
from scipy.stats import ttest_ind

for p in [0.85, 0.90, 0.95]:

    alpha = 1 - p

    p_value = ttest_ind(
        df[df['SEX'] == 1]['Y'],
        df[df['SEX'] == 2]['Y']
    ).pvalue

    print(f"Confidence = {p:.0%}")

    if p_value < alpha:
        print("degree of diabetes progression is different between men and women")
    else:
        print("No significant difference")

    print(f"test p-value = {p_value:.4f}\n")
# Out:
# Confidence = 85%
# No significant difference
# test p-value = 0.3664
#
# Confidence = 90%
# No significant difference
# test p-value = 0.3664
#
# Confidence = 95%
# No significant difference
# test p-value = 0.3664

# %% [markdown]
# The hypothesis is wrong and there is no clear deffernce in the degree of diabetes progression between the genders.
